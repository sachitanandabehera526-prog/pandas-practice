# %% [markdown]
# # Series

# %%
import pandas as pd
x=[1,2,3,4,5]
var = pd.Series(x,index=['a','b','c','d','e'],dtype="float")
print(var)
# Out:
# a    1.0
# b    2.0
# c    3.0
# d    4.0
# e    5.0
# dtype: float64

# %% [markdown]
# # DataFrame

# %%
import pandas as pd
a=[1,2,3,4,5]
var = pd.DataFrame(a)
print(type(var))
# Out:
# <class 'pandas.DataFrame'>

# %% [markdown]
# # Arithmetic Operations
