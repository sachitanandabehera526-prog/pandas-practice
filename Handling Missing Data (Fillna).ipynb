# %% [markdown]
# # Fillna

# %%
import pandas as pd
var = pd.read_csv(r"C:\Users\sachi\OneDrive\product__table 1.csv")
var
# Out:
#     ID   Product Name     Category  Price ($)  Stock Qty     Supplier
# 0    1      Alpha Pen   Stationery        1.5      120.0   OfficeMart
# 1    2  Beta Notebook   Stationery        3.2       85.0   PaperWorld
# 2    3    Gamma Chair    Furniture       45.0       40.0      FurniCo
# 3    4     Delta Desk    Furniture      120.0       25.0          NaN
# 4    5   Epsilon Lamp     Lighting       18.5       60.0   BrightLite
# 5    6     Zeta Mouse  Electronics       12.0      150.0          NaN
# 6    7   Eta Keyboard  Electronics       25.0       90.0     TechZone
# 7    8  Theta Monitor  Electronics      150.0       35.0   VisionTech
# 8    9   Iota Printer          NaN      200.0       20.0     PrintMax
# 9   10    Kappa Phone  Electronics      350.0       50.0    MobileHub
# 10  11   Lambda Cable  Electronics        5.0        NaN    WireWorks
# 11  12         Mu Mug          NaN        4.5      200.0          NaN
# ...

# %%
var.fillna("Python")
# Out:
#     ID   Product Name     Category Price ($) Stock Qty     Supplier
# 0    1      Alpha Pen   Stationery       1.5     120.0   OfficeMart
# 1    2  Beta Notebook   Stationery       3.2      85.0   PaperWorld
# 2    3    Gamma Chair    Furniture      45.0      40.0      FurniCo
# 3    4     Delta Desk    Furniture     120.0      25.0       Python
# 4    5   Epsilon Lamp     Lighting      18.5      60.0   BrightLite
# 5    6     Zeta Mouse  Electronics      12.0     150.0       Python
# 6    7   Eta Keyboard  Electronics      25.0      90.0     TechZone
# 7    8  Theta Monitor  Electronics     150.0      35.0   VisionTech
# 8    9   Iota Printer       Python     200.0      20.0     PrintMax
# 9   10    Kappa Phone  Electronics     350.0      50.0    MobileHub
# 10  11   Lambda Cable  Electronics       5.0    Python    WireWorks
# 11  12         Mu Mug       Python       4.5     200.0       Python
# 12  13       Nu Plate       Python    Python     180.0  HomeEssence
# ...

# %%
var.fillna({"Category":"Java","Supplier":"Python"})
# Out:
#     ID   Product Name     Category  Price ($)  Stock Qty     Supplier
# 0    1      Alpha Pen   Stationery        1.5      120.0   OfficeMart
# 1    2  Beta Notebook   Stationery        3.2       85.0   PaperWorld
# 2    3    Gamma Chair    Furniture       45.0       40.0      FurniCo
# 3    4     Delta Desk    Furniture      120.0       25.0       Python
# 4    5   Epsilon Lamp     Lighting       18.5       60.0   BrightLite
# 5    6     Zeta Mouse  Electronics       12.0      150.0       Python
# 6    7   Eta Keyboard  Electronics       25.0       90.0     TechZone
# 7    8  Theta Monitor  Electronics      150.0       35.0   VisionTech
# 8    9   Iota Printer         Java      200.0       20.0     PrintMax
# 9   10    Kappa Phone  Electronics      350.0       50.0    MobileHub
# 10  11   Lambda Cable  Electronics        5.0        NaN    WireWorks
# 11  12         Mu Mug         Java        4.5      200.0       Python
# ...

# %%
var.ffill(axis =0)
# Out:
#     ID   Product Name     Category  Price ($)  Stock Qty     Supplier
# 0    1      Alpha Pen   Stationery        1.5      120.0   OfficeMart
# 1    2  Beta Notebook   Stationery        3.2       85.0   PaperWorld
# 2    3    Gamma Chair    Furniture       45.0       40.0      FurniCo
# 3    4     Delta Desk    Furniture      120.0       25.0      FurniCo
# 4    5   Epsilon Lamp     Lighting       18.5       60.0   BrightLite
# 5    6     Zeta Mouse  Electronics       12.0      150.0   BrightLite
# 6    7   Eta Keyboard  Electronics       25.0       90.0     TechZone
# 7    8  Theta Monitor  Electronics      150.0       35.0   VisionTech
# 8    9   Iota Printer  Electronics      200.0       20.0     PrintMax
# 9   10    Kappa Phone  Electronics      350.0       50.0    MobileHub
# 10  11   Lambda Cable  Electronics        5.0       50.0    WireWorks
# 11  12         Mu Mug  Electronics        4.5      200.0    WireWorks
# ...

# %%
var.bfill(axis =1)
# Out:
#     ID   Product Name     Category Price ($)  Stock Qty     Supplier
# 0    1      Alpha Pen   Stationery       1.5      120.0   OfficeMart
# 1    2  Beta Notebook   Stationery       3.2       85.0   PaperWorld
# 2    3    Gamma Chair    Furniture      45.0       40.0      FurniCo
# 3    4     Delta Desk    Furniture     120.0       25.0          NaN
# 4    5   Epsilon Lamp     Lighting      18.5       60.0   BrightLite
# 5    6     Zeta Mouse  Electronics      12.0      150.0          NaN
# 6    7   Eta Keyboard  Electronics      25.0       90.0     TechZone
# 7    8  Theta Monitor  Electronics     150.0       35.0   VisionTech
# 8    9   Iota Printer        200.0     200.0       20.0     PrintMax
# 9   10    Kappa Phone  Electronics     350.0       50.0    MobileHub
# 10  11   Lambda Cable  Electronics       5.0  WireWorks    WireWorks
# 11  12         Mu Mug          4.5       4.5      200.0          NaN
# 12  13       Nu Plate        180.0     180.0      180.0  HomeEssence
# ...

# %%
var.fillna("Python",limit = 3)
# Out:
#     ID   Product Name     Category Price ($) Stock Qty     Supplier
# 0    1      Alpha Pen   Stationery       1.5     120.0   OfficeMart
# 1    2  Beta Notebook   Stationery       3.2      85.0   PaperWorld
# 2    3    Gamma Chair    Furniture      45.0      40.0      FurniCo
# 3    4     Delta Desk    Furniture     120.0      25.0       Python
# 4    5   Epsilon Lamp     Lighting      18.5      60.0   BrightLite
# 5    6     Zeta Mouse  Electronics      12.0     150.0       Python
# 6    7   Eta Keyboard  Electronics      25.0      90.0     TechZone
# 7    8  Theta Monitor  Electronics     150.0      35.0   VisionTech
# 8    9   Iota Printer       Python     200.0      20.0     PrintMax
# 9   10    Kappa Phone  Electronics     350.0      50.0    MobileHub
# 10  11   Lambda Cable  Electronics       5.0    Python    WireWorks
# 11  12         Mu Mug       Python       4.5     200.0       Python
# 12  13       Nu Plate       Python    Python     180.0  HomeEssence
# ...
